# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Carga de la base de datos

# %%
ruta = "../datos/online_retail_customer_churn.csv"

datos = pd.read_csv(ruta)

# %% [markdown]
# # Exploracion de Datos

# %%
datos.head()
# Out:
#    Customer_ID  Age Gender  Annual_Income  Total_Spend  Years_as_Customer  \
# 0            1   62  Other          45.15      5892.58                  5
# 1            2   65   Male          79.51      9025.47                 13
# 2            3   18   Male          29.19       618.83                 13
# 3            4   21  Other          79.63      9110.30                  3
# 4            5   21  Other          77.66      5390.88                 15
#
#    Num_of_Purchases  Average_Transaction_Amount  Num_of_Returns  \
# 0                22                      453.80               2
# 1                77                       22.90               2
# 2                71                       50.53               5
# 3                33                      411.83               5
# 4                43                      101.19               3
#
#    Num_of_Support_Contacts  Satisfaction_Score  Last_Purchase_Days_Ago  \
# ...

# %%
datos.tail()
# Out:
#      Customer_ID  Age  Gender  Annual_Income  Total_Spend  Years_as_Customer  \
# 995          996   54    Male         143.72      1089.09                  2
# 996          997   19    Male         164.19      3700.24                  9
# 997          998   47  Female         113.31       705.85                 17
# 998          999   23    Male          72.98      3891.60                  7
# 999         1000   34   Other         134.86      3956.71                 15
#
#      Num_of_Purchases  Average_Transaction_Amount  Num_of_Returns  \
# 995                29                       77.75               0
# 996                90                       34.45               6
# 997                69                      187.37               7
# 998                31                      483.80               1
# 999                48                      420.91               6
#
#      Num_of_Support_Contacts  Satisfaction_Score  Last_Purchase_Days_Ago  \
# ...

# %% [markdown]
# ### Exploracion

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_ID                 1000 non-null   int64
#  1   Age                         1000 non-null   int64
#  2   Gender                      1000 non-null   object
#  3   Annual_Income               1000 non-null   float64
#  4   Total_Spend                 1000 non-null   float64
#  5   Years_as_Customer           1000 non-null   int64
#  6   Num_of_Purchases            1000 non-null   int64
#  7   Average_Transaction_Amount  1000 non-null   float64
#  8   Num_of_Returns              1000 non-null   int64
#  9   Num_of_Support_Contacts     1000 non-null   int64
#  10  Satisfaction_Score          1000 non-null   int64
#  11  Last_Purchase_Days_Ago      1000 non-null   int64
#  12  Email_Opt_In                1000 non-null   bool
# ...

# %%
datos.describe()
# Out:
#        Customer_ID          Age  Annual_Income  Total_Spend  \
# count  1000.000000  1000.000000    1000.000000   1000.00000
# mean    500.500000    43.267000     111.962960   5080.79265
# std     288.819436    15.242311      52.844111   2862.12335
# min       1.000000    18.000000      20.010000    108.94000
# 25%     250.750000    30.000000      67.800000   2678.67500
# 50%     500.500000    43.000000     114.140000   4986.19500
# 75%     750.250000    56.000000     158.452500   7606.47000
# max    1000.000000    69.000000     199.730000   9999.64000
#
#        Years_as_Customer  Num_of_Purchases  Average_Transaction_Amount  \
# count        1000.000000       1000.000000                 1000.000000
# mean            9.727000         49.456000                  266.876530
# std             5.536346         28.543595                  145.873445
# min             1.000000          1.000000                   10.460000
# ...

# %%
datos['Gender'].value_counts()
# Out:
# Gender
# Female    342
# Male      334
# Other     324
# Name: count, dtype: int64

# %%
datos['Promotion_Response'].value_counts()
# Out:
# Promotion_Response
# Unsubscribed    361
# Responded       338
# Ignored         301
# Name: count, dtype: int64

# %% [markdown]
# ### Control de valores nulos

# %% [markdown]
# No hay valores nulos en el dataset

# %%
datos.isnull().sum()
# Out:
# Customer_ID                   0
# Age                           0
# Gender                        0
# Annual_Income                 0
# Total_Spend                   0
# Years_as_Customer             0
# Num_of_Purchases              0
# Average_Transaction_Amount    0
# Num_of_Returns                0
# Num_of_Support_Contacts       0
# Satisfaction_Score            0
# Last_Purchase_Days_Ago        0
# Email_Opt_In                  0
# Promotion_Response            0
# Target_Churn                  0
# dtype: int64

# %% [markdown]
# # Limpieza

# %% [markdown]
# ### Renombrar variables

# %%
datos.rename(columns={'Age': 'Edad', 'Gender': 'Genero', 'Annual_Income':'Ingreso_Anual',
                      'Total_Spend':'Total_Gastado', 'Years_as_Customer':'Anios_como_cliente',
                      'Num_of_Purchases':'Numeros_Compras', 
                      'Average_Transaction_Amount':'Importe_Promedio_Transaccion',
                      'Num_of_Returns': 'Numero_de_Devoluciones',
                      'Num_of_Support_Contacts':'Cantidad_de_Contactos_Soporte',
                      'Satisfaction_Score': 'Nivel_Satisfaccion',
                      'Last_Purchase_Days_Ago':'Ultimo_dia_compra',
                      'Email_Opt_In':'Esta_Suscripto_via_Email',
                      'Promotion_Response':'Respuesta_a_Promocion',
                      'Target_Churn':'Target'}, inplace=True)

# %%
datos.head()
# Out:
#    Customer_ID  Edad Genero  Ingreso_Anual  Total_Gastado  Anios_como_cliente  \
# 0            1    62  Other          45.15        5892.58                   5
# 1            2    65   Male          79.51        9025.47                  13
# 2            3    18   Male          29.19         618.83                  13
# 3            4    21  Other          79.63        9110.30                   3
# 4            5    21  Other          77.66        5390.88                  15
#
#    Numeros_Compras  Importe_Promedio_Transaccion  Numero_de_Devoluciones  \
# 0               22                        453.80                       2
# 1               77                         22.90                       2
# 2               71                         50.53                       5
# 3               33                        411.83                       5
# 4               43                        101.19                       3
#
# ...

# %% [markdown]
# ### Cambio de tipo de variable

# %%
datos['Genero'].astype('string')
# Out:
# 0       Other
# 1        Male
# 2        Male
# 3       Other
# 4       Other
#         ...
# 995      Male
# 996      Male
# 997    Female
# 998      Male
# 999     Other
# Name: Genero, Length: 1000, dtype: string

# %%
datos['Respuesta_a_Promocion'].astype('string')
# Out:
# 0         Responded
# 1         Responded
# 2         Responded
# 3           Ignored
# 4      Unsubscribed
#            ...
# 995         Ignored
# 996       Responded
# 997    Unsubscribed
# 998       Responded
# 999         Ignored
# Name: Respuesta_a_Promocion, Length: 1000, dtype: string

# %%
datos['Genero'] = datos['Genero'].str.lower()
datos['Genero'].value_counts()
# Out:
# Genero
# female    342
# male      334
# other     324
# Name: count, dtype: int64

# %%
datos['Respuesta_a_Promocion'] = datos['Respuesta_a_Promocion'].str.lower()
datos['Respuesta_a_Promocion'].value_counts()
# Out:
# Respuesta_a_Promocion
# unsubscribed    361
# responded       338
# ignored         301
# Name: count, dtype: int64

# %% [markdown]
# ### Datos Duplicados

# %%
datos.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Escalado de variables

# %%
datos['Ingreso_Anual'] = datos['Ingreso_Anual']*1000
datos.head()
# Out:
#    Customer_ID  Edad Genero  Ingreso_Anual  Total_Gastado  Anios_como_cliente  \
# 0            1    62  other        45150.0        5892.58                   5
# 1            2    65   male        79510.0        9025.47                  13
# 2            3    18   male        29190.0         618.83                  13
# 3            4    21  other        79630.0        9110.30                   3
# 4            5    21  other        77660.0        5390.88                  15
#
#    Numeros_Compras  Importe_Promedio_Transaccion  Numero_de_Devoluciones  \
# 0               22                        453.80                       2
# 1               77                         22.90                       2
# 2               71                         50.53                       5
# 3               33                        411.83                       5
# 4               43                        101.19                       3
#
# ...

# %%
datos['Esta_Suscripto_via_Email'] = datos['Esta_Suscripto_via_Email'].astype(int)
datos.head()
# Out:
#    Customer_ID  Edad Genero  Ingreso_Anual  Total_Gastado  Anios_como_cliente  \
# 0            1    62  other        45150.0        5892.58                   5
# 1            2    65   male        79510.0        9025.47                  13
# 2            3    18   male        29190.0         618.83                  13
# 3            4    21  other        79630.0        9110.30                   3
# 4            5    21  other        77660.0        5390.88                  15
#
#    Numeros_Compras  Importe_Promedio_Transaccion  Numero_de_Devoluciones  \
# 0               22                        453.80                       2
# 1               77                         22.90                       2
# 2               71                         50.53                       5
# 3               33                        411.83                       5
# 4               43                        101.19                       3
#
# ...

# %%
datos['Target'] = datos['Target'].astype(int)
datos.head()
# Out:
#    Customer_ID  Edad Genero  Ingreso_Anual  Total_Gastado  Anios_como_cliente  \
# 0            1    62  other        45150.0        5892.58                   5
# 1            2    65   male        79510.0        9025.47                  13
# 2            3    18   male        29190.0         618.83                  13
# 3            4    21  other        79630.0        9110.30                   3
# 4            5    21  other        77660.0        5390.88                  15
#
#    Numeros_Compras  Importe_Promedio_Transaccion  Numero_de_Devoluciones  \
# 0               22                        453.80                       2
# 1               77                         22.90                       2
# 2               71                         50.53                       5
# 3               33                        411.83                       5
# 4               43                        101.19                       3
#
# ...

# %%
datos.describe()
# Out:
#        Customer_ID         Edad  Ingreso_Anual  Total_Gastado  \
# count  1000.000000  1000.000000    1000.000000     1000.00000
# mean    500.500000    43.267000  111962.960000     5080.79265
# std     288.819436    15.242311   52844.111367     2862.12335
# min       1.000000    18.000000   20010.000000      108.94000
# 25%     250.750000    30.000000   67800.000000     2678.67500
# 50%     500.500000    43.000000  114140.000000     4986.19500
# 75%     750.250000    56.000000  158452.500000     7606.47000
# max    1000.000000    69.000000  199730.000000     9999.64000
#
#        Anios_como_cliente  Numeros_Compras  Importe_Promedio_Transaccion  \
# count         1000.000000      1000.000000                   1000.000000
# mean             9.727000        49.456000                    266.876530
# std              5.536346        28.543595                    145.873445
# min              1.000000         1.000000                     10.460000
# ...

# %% [markdown]
# # Guardado del dataset

# %%
ruta_guardado = "../datos/dataset_retail_limpio.csv"
datos.to_csv(ruta_guardado, index=False)

# %% [markdown]
# # Analisis Univariado
